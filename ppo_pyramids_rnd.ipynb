# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget "https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip" -O ./training-envs-executables/linux/Pyramids.zip

# %%
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/Pyramids.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/Pyramids/Pyramids

# %%
# !cat config/ppo/PyramidsRND.yaml

# %%
import yaml
from huggingface_hub import notebook_login

# %%
config = {
    "behaviors": {
        "Pyramids": {
            "trainer_type": "ppo",
            "hyperparameters": {
                "batch_size": 128,
                "buffer_size": 2048,
                "learning_rate": 0.0003,
                "beta": 0.01,
                "epsilon": 0.2,
                "lambd": 0.95,
                "num_epoch": 3,
                "learning_rate_schedule": "linear"
            },
            "network_settings": {
                "normalize": False,
                "hidden_units": 512,
                "num_layers": 2,
                "vis_encode_type": "simple"
            },
            "reward_signals": {
                "extrinsic": {
                    "gamma": 0.99,
                    "strength": 1.0
                },
                "rnd": {
                    "gamma": 0.99,
                    "strength": 0.01,
                    "network_settings": {
                        "hidden_units": 64,
                        "num_layers": 3
                    },
                    "learning_rate": 0.0001
                }
            },
            "keep_checkpoints": 5,
            "max_steps": 1000000,
            "time_horizon": 128,
            "summary_freq": 30000
        }
    }
}

# %%
with open("./config/ppo/PyramidsRND.yaml", "w") as f:
    yaml.dump(config, f)

# %%
# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./training-envs-executables/linux/Pyramids/Pyramids --run-id="ppo_pyramids_rnd" --no-graphics

# %%
notebook_login()

# %%
# !mlagents-push-to-hf --run-id="ppo_pyramids_rnd" --local-dir="./results/ppo_pyramids_rnd" --repo-id="jaymanvirk/ppo_pyramids_rnd" --commit-message="initial commit"
